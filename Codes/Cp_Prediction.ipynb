# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel('1-s2.0-S0032386121001816-mmc2.xlsx')

# %%
df
# Out:
#                            name  total atoms  total bonds  total angles
# 0      Poly(iso-butyl acrylate)           23           22            40  \
# 1        Poly(n-butyl acrylate)           23           22            40
# 2          Poly(ethyl acrylate)           17           16            28
# 3         Poly(methyl acrylate)           14           13            22
# 4           1,4-Poly(butadiene)           12           11            18
# ..                          ...          ...          ...           ...
# 63       Poly(diethyl siloxane)           18           17            31
# 64     Poly(dimethyl itaconate)           23           22            38
# 65      Poly(dimethyl siloxane)           12           11            19
# 66  Poly(4-hydroxybenzoic acid)           15           15            22
# 67                          PAS           47           50            80
#
#     total dihedrals  total atom types  total bond types  total angle types
# 0                54                 6                 7                 13  \
# 1                56                 6                 7                 13
# 2                37                 6                 7                 12
# 3                29                 6                 7                 11
# 4                25                 4                 4                  5
# ..              ...               ...               ...                ...
# 63               39                 5                 6                  9
# 64               49                 6                 7                 11
# 65               21                 5                 5                  7
# 66               37                 6                 7                  8
# 67              140                 5                 5                  8
#
#     total dihedral types  C1  ...  H3-C2-C1-H1  N1-C2-C1-C1  H2-C1-O2-C2
# 0                     10   6  ...            0            0            2  \
# 1                     11   6  ...            0            0            2
# 2                      9   4  ...            0            0            2
# 3                      9   3  ...            0            0            2
# 4                      5   2  ...            6            0            0
# ..                   ...  ..  ...          ...          ...          ...
# 63                     3   4  ...            0            0            0
# 64                     8   5  ...            0            0            6
# 65                     1   2  ...            0            0            0
# 66                     3   0  ...            0            0            0
# 67                     4   0  ...            0            0            0
#
#     C1-H4-C2-O1  C1-O1-C2-O3  H1-C1-C2-C2  H1-C1-C1-H1  H1-C1-C1-N1  Mol Wt
# 0             0            0            0           12            0  128.17  \
# 1             0            0            0           16            0  128.17
# 2             0            0            0            6            0  100.12
# 3             0            0            0            0            0   86.09
# 4             0            0           12            0            0   54.09
# ..          ...          ...          ...          ...          ...     ...
# 63            0            0            0           12            0  102.21
# 64            0            0            0            5            0  158.16
# 65            0            0            0            0            0   74.15
# 66            0            0            0            0            0  120.11
# 67            0            0            0            0            0  140.16
#
#     Cp (J/mol-K)
# 0        232.090
# 1        233.280
# 2        178.880
# 3        151.990
# 4        106.000
# ..           ...
# 63       165.417
# 64       208.507
# 65       118.000
# 66       122.600
# 67       141.400
#
# [68 rows x 190 columns]

# %%
X = df.drop(['name','Cp (J/mol-K)'],axis=1)

# %%
y = df['Cp (J/mol-K)']

# %%
X_train, X_test,y_train, y_test = train_test_split(X,y, random_state=10, test_size=0.25, shuffle=True)

# %%
regr = RandomForestRegressor(max_depth=5, random_state=0)

# %%
regr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5, random_state=0)

# %%
regr.score(X_train,y_train)
# Out:
# 0.9807480123360904

# %%
regr.score(X_test,y_test)
# Out:
# 0.9525865160878539

# %%
train_error = regr.predict(X_train)-y_train
test_error = regr.predict(X_test)-y_test

# %%
train = []
test = []

for i in range(0,len(X_train)):
    train.append(i)

for i in range(0,len(X_test)):
    test.append(i)

# %%
plt.scatter(train_error)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9871/2535974535.py in <module>
# ----> 1 plt.scatter(train_error)
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
# Out:
# Index([50, 26, 66, 56, 10, 61, 23, 34, 54, 18,  4, 31,  1, 12, 37, 44, 30, 22,
#        65, 38, 63, 53,  5, 13, 14, 59, 57, 33, 43, 24, 11, 47, 52, 16, 51, 36,
#        40, 42,  0, 67,  8, 58, 49, 62, 48, 29, 25, 28, 64, 15,  9],
#       dtype='int64')
